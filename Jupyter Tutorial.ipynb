# %% [markdown]
# # Description
#
# This file contains basic code to test out jupyter notebook and libraries like matplotlib and numpy. The intention of making this file was to use it as a reference for syntax and as a trial file to mess around with the different features of jupyter. Feel free to use this as a reference for learning as well

# %%
print("hello world")
x = 55
y=75
print(x+y)
# Out:
# hello world
# 130

# %%
import sys

# %%
# !conda install --yes --prefix {sys.prefix} numpy 

#installs numpy package, !conda install numpy works as well
# Out:
# ...
# Solving environment: done
#
# # All requested packages already installed.

# %%
import numpy as np

# %%
# !conda install matplotlib
import matplotlib.pyplot as plt
# Out:
# ...
# Solving environment: done
#
# # All requested packages already installed.

# %% [markdown]
# #### We have now installed and imported numpy and matplotlib. If you were to make a new notebook, you won't have to install these libraries again and can directly import them. We have also only imported pyplot from matplotlib and not the enitre library

# %%
# %matplotlib inline

# %%
x = np.array([1,2,3,4])
y = np.array([2,4,6,8])
plt.plot(x,y,marker='o')
plt.show()

# %%
a = [2,3,4,5,6,7,8,9,29,8,5,13,11,22,33]
b = [4,7,8,9,10,11,12,13,55,43,2,4,11,22,33]
plt.scatter(a,b, marker='x')
plt.show()

# %%
c = np.linspace(-20, 20,100)
d = c**2

plt.plot(c,d)
plt.show()

# %%
m = 5
e = m*c


fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.spines['left'].set_position(('data', 0))
ax.spines['bottom'].set_position(('data', 0))
plt.plot(c,e)
plt.show()
